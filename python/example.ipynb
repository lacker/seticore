# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import viewer
import numpy as np

# %%
events = list(viewer.read_events("../data/voyager.events"))

# %%
for h in events[0].hits: viewer.show_hit(h)
# Out:
# hit with source VOYAGER-1, incoherent beam, 8419.56539 MHz, 22.3 SNR, -0.367 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 0.00000 MHz, 0.0 SNR, 0.000 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 8419.56515 MHz, 11.0 SNR, -0.408 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 0.00000 MHz, 0.0 SNR, 0.000 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 8419.56489 MHz, 18.5 SNR, -0.418 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 0.00000 MHz, 0.0 SNR, 0.000 Hz/s drift:

# %%
for h in events[1].hits: viewer.show_hit(h)
# Out:
# hit with source VOYAGER-1, incoherent beam, 8419.54273 MHz, 192.9 SNR, -0.357 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 0.00000 MHz, 0.0 SNR, 0.000 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 8419.54249 MHz, 82.8 SNR, -0.388 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 0.00000 MHz, 0.0 SNR, 0.000 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 8419.54224 MHz, 145.2 SNR, -0.439 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 0.00000 MHz, 0.0 SNR, 0.000 Hz/s drift:

# %%
for h in events[2].hits: viewer.show_hit(h)
# Out:
# hit with source VOYAGER-1, incoherent beam, 8419.52040 MHz, 22.6 SNR, -0.367 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 0.00000 MHz, 0.0 SNR, 0.000 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 8419.51983 MHz, 10.5 SNR, -0.378 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 0.00000 MHz, 0.0 SNR, 0.000 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 8419.51990 MHz, 19.0 SNR, -0.418 Hz/s drift:
# hit with source VOYAGER-1, incoherent beam, 0.00000 MHz, 0.0 SNR, 0.000 Hz/s drift:
