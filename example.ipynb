# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import viewer

# %%
for hit in viewer.read_hits("data/voyager.hits"):
    viewer.show_hit(hit)
# Out:
# hit at 8419.3197 MHz with 29.3 SNR, -0.367 Hz/s drift:
# hit at 8419.3194 MHz with 30.6 SNR, -0.398 Hz/s drift:
# hit at 8419.2970 MHz with 245.8 SNR, -0.378 Hz/s drift:
# hit at 8419.2747 MHz with 28.9 SNR, -0.388 Hz/s drift:
# hit at 8419.2744 MHz with 31.2 SNR, -0.398 Hz/s drift:
